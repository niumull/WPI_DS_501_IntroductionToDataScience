# %% [markdown]
# # Example 1. Authorizing an application to access Twitter account data

# %%
# I had to add this because the ipython notebook could not find the Twitter library on my computer.
# You may not need to add these first two lines
import sys
sys.path.append('/home/matt/Enthought/Canopy_64bit/User/lib/python2.7/site-packages')
import twitter
# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

# CONSUMER_KEY = 'Tx8GozuzaraJO89LypsTqFUNM'
# CONSUMER_SECRET ='uC0KPaRZjGY0qoNJAxBQb0jbb3Us4DXJVKFCP1qtSfjFgbRvd0'
# OAUTH_TOKEN = '571213367-BC7MYnWpLbvy2AYhvqCu6Fh1EIeFasPxo0Y8uBEn'
# OAUTH_TOKEN_SECRET = 'KA9GddiLbVwummLoSGmDYMNQFVaR3P4YiGo7Zs6D5e7Qz'

CONSUMER_KEY = 'YBicfvPPR7YmsJdFtd8qGATmI'
CONSUMER_SECRET ='YYXKSBw5n6b5dpbwmMfZTjqJcUnDQm6fxlNUEnf63k5idJsj2m'
OAUTH_TOKEN = '774076984561430528-1ENguVW2E40PSue6YWnDuCBUyASjhGB'
OAUTH_TOKEN_SECRET = 'ZcjrXboPxPmGEXzq2n1GQN1s7u8ZAXQeKWDSVIrZxQMkV'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f97a0842ac8>

# %% [markdown]
# # Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
print()
print(us_trends)
# Out:
# [{'trends': [{'query': '%23FelizMartes', 'name': '#FelizMartes', 'url': 'http://twitter.com/search?q=%23FelizMartes', 'promoted_content': None, 'tweet_volume': 35529}, {'query': '%23RoaldDahlDay', 'name': '#RoaldDahlDay', 'url': 'http://twitter.com/search?q=%23RoaldDahlDay', 'promoted_content': None, 'tweet_volume': 58062}, {'query': '%23%D8%A7%D8%B3%D9%85_%D8%A7%D8%AE%D8%B1_%D8%A7%D9%84%D8%B9%D9%86%D9%82%D9%88%D8%AF_%D8%B9%D9%86%D8%AF%D9%83%D9%85', 'name': '#اسم_اخر_العنقود_عندكم', 'url': 'http://twitter.com/search?q=%23%D8%A7%D8%B3%D9%85_%D8%A7%D8%AE%D8%B1_%D8%A7%D9%84%D8%B9%D9%86%D9%82%D9%88%D8%AF_%D8%B9%D9%86%D8%AF%D9%83%D9%85', 'promoted_content': None, 'tweet_volume': 24057}, {'query': '%23%E3%83%AA%E3%83%97%E3%81%A7%E6%9D%A5%E3%81%9F%E3%82%82%E3%81%AE%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6%E3%81%BB%E3%82%93%E3%81%AE%E5%B0%91%E3%81%97%E8%AA%9E%E3%82%8B', 'name': '#リプで来たものについてほんの少し語る', 'url': 'http://twitter.com/search?q=%23%E3%83%AA%E3%83%97%E3%81%A7%E6%9D%A5%E3%81%9F%E3%82%82%E3%81%AE%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6%E3%81%BB%E3%82%93%E3%81%AE%E5%B0%91%E3%81%97%E8%AA%9E%E3%82%8B', 'promoted_content': None, 'tweet_volume': 37778}, {'query': '%23TIMYSantorini', 'name': '#TIMYSantorini', 'url': 'http://twitter.com/search?q=%23TIMYSantorini', 'promoted_content': None, 'tweet_volume': 719941}, {'query': '%22Rita+Barber%C3%A1%22', 'name': 'Rita Barberá', 'url': 'http://twitter.com/search?q=%22Rita+Barber%C3%A1%22', 'promoted_content': None, 'tweet_volume': 25755}, {'query': '%E5%AE%AE%E6%B2%A2%E3%81%95%E3%82%93', 'name': '宮沢さん', 'url': 'http://twitter.com/search?q=%E5%AE%AE%E6%B2%A2%E3%81%95%E3%82%93', 'promoted_content': None, 'tweet_volume': 16641}, {'query': '%22EST%C3%81+LLOVIENDO%22', 'name': 'ESTÁ LLOVIENDO', 'url': 'http://twitter.com/search?q=%22EST%C3%81+LLOVIENDO%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Acci%C3%B3n+Democr%C3%A1tica%22', 'name': 'Acción Democrática', 'url': 'http://twitter.com/search?q=%22Acci%C3%B3n+Democr%C3%A1tica%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23Pare%C3%A7oNormalMas', 'name': '#PareçoNormalMas', 'url': 'http://twitter.com/search?q=%23Pare%C3%A7oNormalMas', 'promoted_content': None, 'tweet_volume': 10458}, {'query': '%23Tordesillas', 'name': '#Tordesillas', 'url': 'http://twitter.com/search?q=%23Tordesillas', 'promoted_content': None, 'tweet_volume': 63027}, {'query': '%23RespectNiall', 'name': '#RespectNiall', 'url': 'http://twitter.com/search?q=%23RespectNiall', 'promoted_content': None, 'tweet_volume': 50847}, {'query': '%23BarcelonaGlobalPremiere', 'name': '#BarcelonaGlobalPremiere', 'url': 'http://twitter.com/search?q=%23BarcelonaGlobalPremiere', 'promoted_content': None, 'tweet_volume': 535519}, {'query': '%23RussianRoulette1stWin', 'name': '#RussianRoulette1stWin', 'url': 'http://twitter.com/search?q=%23RussianRoulette1stWin', 'promoted_content': None, 'tweet_volume': 46504}, {'query': '%23heatwave', 'name': '#heatwave', 'url': 'http://twitter.com/search?q=%23heatwave', 'promoted_content': None, 'tweet_volume': 12497}, {'query': '%23ZumaQandA', 'name': '#ZumaQandA', 'url': 'http://twitter.com/search?q=%23ZumaQandA', 'promoted_content': None, 'tweet_volume': 13096}, {'query': '%23iOS10', 'name': '#iOS10', 'url': 'http://twitter.com/search?q=%23iOS10', 'promoted_content': None, 'tweet_volume': 21856}, {'query': '%23%D8%A7%D9%84%D8%AD%D8%AC_%D8%A8%D8%AF%D9%88%D9%86_%D8%A7%D9%8A%D8%B1%D8%A7%D9%86_%D8%AA%D9%86%D8%B8%D9%8A%D9%85_%D9%88%D8%A7%D9%85%D8%A7%D9%86', 'name': '#الحج_بدون_ايران_تنظيم_وامان', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AD%D8%AC_%D8%A8%D8%AF%D9%88%D9%86_%D8%A7%D9%8A%D8%B1%D8%A7%D9%86_%D8%AA%D9%86%D8%B8%D9%8A%D9%85_%D9%88%D8%A7%D9%85%D8%A7%D9%86', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23TupacShakur', 'name': '#TupacShakur', 'url': 'http://twitter.com/search?q=%23TupacShakur', 'promoted_content': None, 'tweet_volume': 14198}, {'query': '%23TuesdayMotivation', 'name': '#TuesdayMoti ...
#
# [{'trends': [{'query': '%23TuesdayMotivation', 'name': '#TuesdayMotivation', 'url': 'http://twitter.com/search?q=%23TuesdayMotivation', 'promoted_content': None, 'tweet_volume': 17093}, {'query': '%23ColorRush', 'name': '#ColorRush', 'url': 'http://twitter.com/search?q=%23ColorRush', 'promoted_content': None, 'tweet_volume': 23489}, {'query': '%23TupacShakur', 'name': '#TupacShakur', 'url': 'http://twitter.com/search?q=%23TupacShakur', 'promoted_content': None, 'tweet_volume': 14198}, {'query': '%23RoaldDahlDay', 'name': '#RoaldDahlDay', 'url': 'http://twitter.com/search?q=%23RoaldDahlDay', 'promoted_content': None, 'tweet_volume': 58062}, {'query': '%23ThingsToTryJustOnce', 'name': '#ThingsToTryJustOnce', 'url': 'http://twitter.com/search?q=%23ThingsToTryJustOnce', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Kevin+Harlan%22', 'name': 'Kevin Harlan', 'url': 'http://twitter.com/search?q=%22Kevin+Harlan%22', 'promoted_content': None, 'tweet_volume': 42015}, {'query': '%22Black+Rifles+Matter%22', 'name': 'Black Rifles Matter', 'url': 'http://twitter.com/search?q=%22Black+Rifles+Matter%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Adblock+Plus%22', 'name': 'Adblock Plus', 'url': 'http://twitter.com/search?q=%22Adblock+Plus%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Yma+Sumac%22', 'name': 'Yma Sumac', 'url': 'http://twitter.com/search?q=%22Yma+Sumac%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22All+Eyez+On+Me%22', 'name': 'All Eyez On Me', 'url': 'http://twitter.com/search?q=%22All+Eyez+On+Me%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Stand+Up+and+Say+So%22', 'name': 'Stand Up and Say So', 'url': 'http://twitter.com/search?q=%22Stand+Up+and+Say+So%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Bill+Ford%22', 'name': 'Bill Ford', 'url': 'http://twitter.com/search?q=%22Bill+Ford%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Chevy+Bolt%22', 'name': 'Chevy Bolt', 'url': 'http://twitter.com/search?q=%22Chevy+Bolt%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Lavilla+School+of+the+Arts%22', 'name': 'Lavilla School of the Arts', 'url': 'http://twitter.com/search?q=%22Lavilla+School+of+the+Arts%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22LT+David+Bakhtiari%22', 'name': 'LT David Bakhtiari', 'url': 'http://twitter.com/search?q=%22LT+David+Bakhtiari%22', 'promoted_content': None, 'tweet_volume': None}, {'query': 'N.C.', 'name': 'N.C.', 'url': 'http://twitter.com/search?q=N.C.', 'promoted_content': None, 'tweet_volume': 85130}, {'query': '%22Kentucky+Gov%22', 'name': 'Kentucky Gov', 'url': 'http://twitter.com/search?q=%22Kentucky+Gov%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%22Lionel+Shriver%22', 'name': 'Lionel Shriver', 'url': 'http://twitter.com/search?q=%22Lionel+Shriver%22', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23DeliveringAlpha', 'name': '#DeliveringAlpha', 'url': 'http://twitter.com/search?q=%23DeliveringAlpha', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23FilmASequel', 'name': '#FilmASequel', 'url': 'http://twitter.com/search?q=%23FilmASequel', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23HappyBirthdayNiall', 'name': '#HappyBirthdayNiall', 'url': 'http://twitter.com/search?q=%23HappyBirthdayNiall', 'promoted_content': None, 'tweet_volume': 642616}, {'query': '%23SupernaturalDay', 'name': '#SupernaturalDay', 'url': 'http://twitter.com/search?q=%23SupernaturalDay', 'promoted_content': None, 'tweet_volume': 88518}, {'query': '%23TravelTuesday', 'name': '#TravelTuesday', 'url': 'http://twitter.com/search?q=%23TravelTuesday', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23WPJustice', 'name': '#WPJustice', 'url': 'http://twitter.com/search?q=%23WPJustice', 'promoted_content': None, 'tweet_volume': None}, {'query': '%23InternationalChocolateDay' ...

# %%
import json
data= json.dumps(us_trends, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
file = open('foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d))
print(d[0].keys())
print(len(d[0]['trends']))
print(d[0]['trends'][27])
# Out:
# 1
# dict_keys(['trends', 'locations', 'as_of', 'created_at'])
# 50
# {'tweet_volume': None, 'name': '#BestColleges', 'query': '%23BestColleges', 'url': 'http://twitter.com/search?q=%23BestColleges', 'promoted_content': None}

# %%
a= [1,2,3,4]
print(a)
print(a[0])
# Out:
# [1, 2, 3, 4]
# 1

# %%
b={'randy':47,'tyler':'cool'}
print(b['randy'])
print(b.keys())
# Out:
# 47
# dict_keys(['randy', 'tyler'])

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

#print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "query": "%23TuesdayMotivation",
#     "name": "#TuesdayMotivation",
#     "url": "http://twitter.com/search?q=%23TuesdayMotivation",
#     "promoted_content": null,
#     "tweet_volume": 17093
#    },
#    {
#     "query": "%23ColorRush",
#     "name": "#ColorRush",
#     "url": "http://twitter.com/search?q=%23ColorRush",
#     "promoted_content": null,
#     "tweet_volume": 23489
#    },
#    {
#     "query": "%23TupacShakur",
#     "name": "#TupacShakur",
#     "url": "http://twitter.com/search?q=%23TupacShakur",
#     "promoted_content": null,
#     "tweet_volume": 14198
#    },
#    {
#     "query": "%23RoaldDahlDay",
#     "name": "#RoaldDahlDay",
#     "url": "http://twitter.com/search?q=%23RoaldDahlDay",
#     "promoted_content": null,
#     "tweet_volume": 58062
#    },
#    {
#     "query": "%23ThingsToTryJustOnce",
#     "name": "#ThingsToTryJustOnce",
#     "url": "http://twitter.com/search?q=%23ThingsToTryJustOnce",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Kevin+Harlan%22",
#     "name": "Kevin Harlan",
#     "url": "http://twitter.com/search?q=%22Kevin+Harlan%22",
#     "promoted_content": null,
#     "tweet_volume": 42015
#    },
#    {
#     "query": "%22Black+Rifles+Matter%22",
#     "name": "Black Rifles Matter",
#     "url": "http://twitter.com/search?q=%22Black+Rifles+Matter%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Adblock+Plus%22",
#     "name": "Adblock Plus",
#     "url": "http://twitter.com/search?q=%22Adblock+Plus%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Yma+Sumac%22",
#     "name": "Yma Sumac",
#     "url": "http://twitter.com/search?q=%22Yma+Sumac%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22All+Eyez+On+Me%22",
#     "name": "All Eyez On Me",
#     "url": "http://twitter.com/search?q=%22All+Eyez+On+Me%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Stand+Up+and+Say+So%22",
#     "name": "Stand Up and Say So",
#     "url": "http://twitter.com/search?q=%22Stand+Up+and+Say+So%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Bill+Ford%22",
#     "name": "Bill Ford",
#     "url": "http://twitter.com/search?q=%22Bill+Ford%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Chevy+Bolt%22",
#     "name": "Chevy Bolt",
#     "url": "http://twitter.com/search?q=%22Chevy+Bolt%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Lavilla+School+of+the+Arts%22",
#     "name": "Lavilla School of the Arts",
#     "url": "http://twitter.com/search?q=%22Lavilla+School+of+the+Arts%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22LT+David+Bakhtiari%22",
#     "name": "LT David Bakhtiari",
#     "url": "http://twitter.com/search?q=%22LT+David+Bakhtiari%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "N.C.",
#     "name": "N.C.",
#     "url": "http://twitter.com/search?q=N.C.",
#     "promoted_content": null,
#     "tweet_volume": 85130
#    },
#    {
#     "query": "%22Kentucky+Gov%22",
#     "name": "Kentucky Gov",
#     "url": "http://twitter.com/search?q=%22Kentucky+Gov%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%22Lionel+Shriver%22",
#     "name": "Lionel Shriver",
#     "url": "http://twitter.com/search?q=%22Lionel+Shriver%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23DeliveringAlpha",
#     "name": "#DeliveringAlpha",
#     "url": "http://twitter.com/search?q=%23DeliveringAlpha",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23FilmASequel",
#     "name": "#FilmASequel",
#     "url": "http://twitter.com/search?q=%23FilmASequel",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23HappyBirthdayNiall",
#     "name": "#HappyBirthdayNiall",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayNiall",
#     "promoted_content": null,
#     "tweet_volume": 642616
#    },
#    {
#     "query": "%23SupernaturalDay",
#     "name": "#SupernaturalDay",
#     "url": "http://twitter.com/search?q=%23SupernaturalDay",
#     "promoted_content": null,
#     "tweet_volume": 88518
#    },
#    {
#     "query": "%23TravelTuesday",
#     "name": "#TravelTuesday",
#     "url": "http://twitter.com/search?q=%23TravelTuesday",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23WPJustice",
#     "name": "#WPJustice",
#     "url": "http://twitter.com/search?q=%23WPJustice",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23InternationalChocolateDay",
#     "name": "#InternationalChocolateDay",
#     "url": "http://twitter.com/search?q=%23InternationalChocolateDay",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23RIP2Pac",
#     "name": "#RIP2Pac",
#     "url": "http://twitter.com/search?q=%23RIP2Pac",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23RussianRoulette1stWin",
#     "name": "#RussianRoulette1stWin",
#     "url": "http://twitter.com/search?q=%23RussianRoulette1stWin",
#     "promoted_content": null,
#     "tweet_volume": 46504
#    },
#    {
#     "query": "%23BestColleges",
#     "name": "#BestColleges",
#     "url": "http://twitter.com/search?q=%23BestColleges",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23FelizMartes",
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "tweet_volume": 35529
#    },
#    {
#     "query": "%23PrimaryDay",
#     "name": "#PrimaryDay",
#     "url": "http://twitter.com/search?q=%23PrimaryDay",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23HotepDay",
#     "name": "#HotepDay",
#     "url": "http://twitter.com/search?q=%23HotepDay",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23NationalPeanutDay",
#     "name": "#NationalPeanutDay",
#     "url": "http://twitter.com/search?q=%23NationalPeanutDay",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23heatwave",
#     "name": "#heatwave",
#     "url": "http://twitter.com/search?q=%23heatwave",
#     "promoted_content": null,
#     "tweet_volume": 12497
#    },
#    {
#     "query": "%232bitTues",
#     "name": "#2bitTues",
#     "url": "http://twitter.com/search?q=%232bitTues",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23ImJustTryingToSay",
#     "name": "#ImJustTryingToSay",
#     "url": "http://twitter.com/search?q=%23ImJustTryingToSay",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23Meranti",
#     "name": "#Meranti",
#     "url": "http://twitter.com/search?q=%23Meranti",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23MakeaMovieHot",
#     "name": "#MakeaMovieHot",
#     "url": "http://twitter.com/search?q=%23MakeaMovieHot",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23TheReader",
#     "name": "#TheReader",
#     "url": "http://twitter.com/search?q=%23TheReader",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23ActionGreen",
#     "name": "#ActionGreen",
#     "url": "http://twitter.com/search?q=%23ActionGreen",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23bookbirthday",
#     "name": "#bookbirthday",
#     "url": "http://twitter.com/search?q=%23bookbirthday",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23dcnlive",
#     "name": "#dcnlive",
#     "url": "http://twitter.com/search?q=%23dcnlive",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23Tordesillas",
#     "name": "#Tordesillas",
#     "url": "http://twitter.com/search?q=%23Tordesillas",
#     "promoted_content": null,
#     "tweet_volume": 63027
#    },
#    {
#     "query": "%23ZumaQandA",
#     "name": "#ZumaQandA",
#     "url": "http://twitter.com/search?q=%23ZumaQandA",
#     "promoted_content": null,
#     "tweet_volume": 13096
#    },
#    {
#     "query": "%23LoveIsAbsolutColors",
#     "name": "#LoveIsAbsolutColors",
#     "url": "http://twitter.com/search?q=%23LoveIsAbsolutColors",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%2313Sep",
#     "name": "#13Sep",
#     "url": "http://twitter.com/search?q=%2313Sep",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23InsectShowsOrMovies",
#     "name": "#InsectShowsOrMovies",
#     "url": "http://twitter.com/search?q=%23InsectShowsOrMovies",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23MeDespiertoYSemeAntoja",
#     "name": "#MeDespiertoYSemeAntoja",
#     "url": "http://twitter.com/search?q=%23MeDespiertoYSemeAntoja",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23ToryBurchSS17",
#     "name": "#ToryBurchSS17",
#     "url": "http://twitter.com/search?q=%23ToryBurchSS17",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "query": "%23HRC33",
#     "name": "#HRC33",
#     "url": "http://twitter.com/search?q=%23HRC33",
#     "promoted_content": null,
#     "tweet_volume": 10338
#    },
#    {
#     "query": "%23HPEGPC",
#     "name": "#HPEGPC",
#     "url": "http://twitter.com/search?q=%23HPEGPC",
#     "promoted_content": null,
#     "tweet_volume": null
#    }
#   ],
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ],
#   "as_of": "2016-09-13T14:09:09Z",
#   "created_at": "2016-09-13T14:03:55Z"
#  }
# ]

# %%
len(us_trends[0]['trends'])
for i in range(50):
    print(us_trends[0]['trends'][i]['url'])
    print(us_trends[0]['trends'][i]['query'])
# Out:
# http://twitter.com/search?q=%23HowToConfuseAMillennial
# %23HowToConfuseAMillennial
# http://twitter.com/search?q=%23SundayFunday
# %23SundayFunday
# http://twitter.com/search?q=%23FakeBirthdayFacts
# %23FakeBirthdayFacts
# http://twitter.com/search?q=%23WeAreReadyForSoloNiall
# %23WeAreReadyForSoloNiall
# http://twitter.com/search?q=%23HappyBirthdayBeyonce
# %23HappyBirthdayBeyonce
# http://twitter.com/search?q=Splyce
# Splyce
# http://twitter.com/search?q=%22Political+Correctness%22
# %22Political+Correctness%22
# http://twitter.com/search?q=Kimball
# Kimball
# http://twitter.com/search?q=%22Dr.+Collins%22
# %22Dr.+Collins%22
# http://twitter.com/search?q=Lackey
# Lackey
# http://twitter.com/search?q=Wozniacki
# Wozniacki
# http://twitter.com/search?q=Adrianza
# Adrianza
# http://twitter.com/search?q=%22Wade+Miley%22
# %22Wade+Miley%22
# http://twitter.com/search?q=%22Lauren+Holiday%22
# %22Lauren+Holiday%22
# http://twitter.com/search?q=%22Brian+Dozier%22
# %22Brian+Dozier%22
# http://twitter.com/search?q=%22Byron+Buxton%22
# %22Byron+Buxton%22
# http://twitter.com/search?q=%22Lucas+Pouille%22
# %22Lucas+Pouille%22
# http://twitter.com/search?q=%22Demaryius+Thomas%22
# %22Demaryius+Thomas%22
# http://twitter.com/search?q=%22Rahim+Moore%22
# %22Rahim+Moore%22
# http://twitter.com/search?q=%22Jumbo+Diaz%22
# %22Jumbo+Diaz%22
# http://twitter.com/search?q=%22Soledad+O%27Brien%22
# %22Soledad+O%27Brien%22
# http://twitter.com/search?q=%23DebbieDownerASongOrMovie
# %23DebbieDownerASongOrMovie
# http://twitter.com/search?q=%23obsessionstonight
# %23obsessionstonight
# http://twitter.com/search?q=%23IndyCarGP
# %23IndyCarGP
# http://twitter.com/search?q=%23ItsBestIfWe
# %23ItsBestIfWe
# http://twitter.com/search?q=%23PAXRUMBLE
# %23PAXRUMBLE
# http://twitter.com/search?q=%23WeLoveYouCalum
# %23WeLoveYouCalum
# http://twitter.com/search?q=%23LondonsBurning
# %23LondonsBurning
# http://twitter.com/search?q=%23ThingsToDoAtARedLight
# %23ThingsToDoAtARedLight
# http://twitter.com/search?q=%23BackToSchoolSongs
# %23BackToSchoolSongs
# http://twitter.com/search?q=%23WINGS
# %23WINGS
# http://twitter.com/search?q=%23SLFLIrvine
# %23SLFLIrvine
# http://twitter.com/search?q=%23DolansMakeMeSmile
# %23DolansMakeMeSmile
# http://twitter.com/search?q=%23SLOENG
# %23SLOENG
# http://twitter.com/search?q=%23NORGER
# %23NORGER
# http://twitter.com/search?q=%23OTHERtone
# %23OTHERtone
# http://twitter.com/search?q=%23NationalWildlifeDay
# %23NationalWildlifeDay
# http://twitter.com/search?q=%23SVKENG
# %23SVKENG
# http://twitter.com/search?q=%23AMJoy
# %23AMJoy
# http://twitter.com/search?q=%23NALCS
# %23NALCS
# http://twitter.com/search?q=%23radglowspoil
# %23radglowspoil
# http://twitter.com/search?q=%23EVOLutiontour
# %23EVOLutiontour
# http://twitter.com/search?q=%23Silverado250
# %23Silverado250
# http://twitter.com/search?q=%23NDvsTex
# %23NDvsTex
# http://twitter.com/search?q=%23shawolselcaday
# %23shawolselcaday
# http://twitter.com/search?q=%23MakeAMovieArrogant
# %23MakeAMovieArrogant
# http://twitter.com/search?q=%23TCMBacklot
# %23TCMBacklot
# http://twitter.com/search?q=%23MyFavChildhoodCartoon
# %23MyFavChildhoodCartoon
# http://twitter.com/search?q=%23BojanglesSo500
# %23BojanglesSo500
# http://twitter.com/search?q=%23NoisyAndFamous
# %23NoisyAndFamous

# %% [markdown]
# # Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#ZumaQandA', '#FelizMartes', '#DeliveringAlpha', '#MeDespiertoYSemeAntoja', '#Tordesillas', '#ColorRush', '#SupernaturalDay', '#ThingsToTryJustOnce', '#TuesdayMotivation', '#TupacShakur', '#heatwave', '#RoaldDahlDay', '#FilmASequel', '#InternationalChocolateDay', '#RussianRoulette1stWin'}

# %%
world_trends[0]['trends'][0]['name']
# Out:
# '#FelizMartes'

# %%
world_trends_set
# Out:
# {'#BarcelonaGlobalPremiere',
#  '#ColorRush',
#  '#CumbreDePaz',
#  '#DeliveringAlpha',
#  '#FelizMartes',
#  '#FiftyShadesDarkerTrailer',
#  '#FilmASequel',
#  '#InternationalChocolateDay',
#  '#KashmirReferendum',
#  '#KenyavsGhana',
#  '#LoveisAbsolutColors',
#  '#MeDespiertoYSemeAntoja',
#  '#MiniDavos',
#  '#MyFilmyPose',
#  '#OopsLoHiceDeNuevo',
#  '#PareçoNormalMas',
#  '#RespectNiall',
#  '#RoaldDahlDay',
#  '#RussianRoulette1stWin',
#  '#SientoMariposasCuando',
#  '#SupernaturalDay',
#  '#TIMYSantorini',
#  '#TercaDetremuraSDV',
#  '#ThingsToTryJustOnce',
#  '#TigerZindaHai',
#  '#TodoBuenMexicano',
#  '#Tordesillas',
#  '#TuesdayMotivation',
#  '#TupacShakur',
#  '#ZumaQandA',
#  '#heatwave',
#  '#iOS10',
#  '#ОсеньФолловитДожди',
#  '#اسم_اخر_العنقود_عندكم',
#  '#الحج_بدون_ايران_تنظيم_وامان',
#  '#اول_صديق_قابلته_عن_طريق_النت',
#  '#ترضي_اختك_تستخدم_تويتر',
#  '#تويت_كانك_سنه_98',
#  '#لن_اتزوج_حتي',
#  '#لو_معك_١٠_مليون_وش_بتسوي',
#  '#あなたのㄘんㄘんを見た時の周りの反応',
#  '#アイコンの戦闘力',
#  '#リプで来たものについてほんの少し語る',
#  '#말_앞에_우웅을_붙이면_귀엽다',
#  '#이_해시를_보는_순간_상황보고',
#  '#자캐의_눈색을_정한_이유',
#  'Acción Democrática',
#  'ESTÁ LLOVIENDO',
#  'Rita Barberá',
#  '宮沢さん'}

# %%
print(u'#\u0645\u0639\u0644\u0645\u064a\u0646_\u0627\u0644\u0627\u0631\u0628\u0639_\u0639\u0627\u0644\u0631\u0627\u062f\u064a\u0648_9090')
# Out:
# #معلمين_الاربع_عالراديو_9090

# %%
print(u'#\u0628\u0642\u0648\u0644_\u0643\u0641\u0627\u064a\u0647_\u0644')
# Out:
# #بقول_كفايه_ل

# %% [markdown]
# # Example 5. Collecting search results

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json

q = '#Kanye' 

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 200
# [
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775698000895209472,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         17,
#                         27
#                     ],
#                     "text": "KanyeWest"
#                 },
#                 {
#                     "indices": [
#                         64,
#                         70
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         96,
#                         111
#                     ],
#                     "text": "SaintPabloTour"
#                 },
#                 {
#                     "indices": [
#                         115,
#                         123
#                     ],
#                     "text": "Atlanta"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "name": "Z100 New York",
#                     "indices": [
#                         3,
#                         15
#                     ],
#                     "id": 19955482,
#                     "screen_name": "Z100NewYork",
#                     "id_str": "19955482"
#                 }
#             ],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/VplRhdE6GG",
#                     "expanded_url": "http://z100.iheart.com/articles/z100-news-451815/kanye-west-fan-climbs-onto-his-15101369/",
#                     "display_url": "z100.iheart.com/articles/z100-\u2026",
#                     "indices": [
#                         139,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "text": "RT @Z100NewYork: #KanyeWest fan attempts to climb to the top of #Kanye's floating stage at this #SaintPabloTour in #Atlanta! WATCH https://\u2026",
#         "retweet_count": 1,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775698000895209472",
#         "retweeted_status": {
#             "lang": "en",
#             "geo": null,
#             "in_reply_to_user_id": null,
#             "id": 775687880769429504,
#             "is_quote_status": false,
#             "in_reply_to_screen_name": null,
#             "coordinates": null,
#             "possibly_sensitive": false,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_status_id": null,
#             "favorited": false,
#             "truncated": false,
#             "favorite_count": 1,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             0,
#                             10
#                         ],
#                         "text": "KanyeWest"
#                     },
#                     {
#                         "indices": [
#                             47,
#                             53
#                         ],
#                         "text": "Kanye"
#                     },
#                     {
#                         "indices": [
#                             79,
#                             94
#                         ],
#                         "text": "SaintPabloTour"
#                     },
#                     {
#                         "indices": [
#                             98,
#                             106
#                         ],
#                         "text": "Atlanta"
#                     }
#                 ],
#                 "user_mentions": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/VplRhdE6GG",
#                         "expanded_url": "http://z100.iheart.com/articles/z100-news-451815/kanye-west-fan-climbs-onto-his-15101369/",
#                         "display_url": "z100.iheart.com/articles/z100-\u2026",
#                         "indices": [
#                             114,
#                             137
#                         ]
#                     }
#                 ]
#             },
#             "text": "#KanyeWest fan attempts to climb to the top of #Kanye's floating stage at this #SaintPabloTour in #Atlanta! WATCH https://t.co/VplRhdE6GG",
#             "retweet_count": 1,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "contributors": null,
#             "retweeted": false,
#             "in_reply_to_user_id_str": null,
#             "id_str": "775687880769429504",
#             "created_at": "Tue Sep 13 13:29:37 +0000 2016",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "user": {
#                 "lang": "en",
#                 "time_zone": null,
#                 "profile_link_color": "2FC2EF",
#                 "profile_use_background_image": true,
#                 "notifications": false,
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/790103653/6a590598f9fcfc998da8299e3618951b.gif",
#                 "listed_count": 1874,
#                 "followers_count": 328277,
#                 "is_translation_enabled": false,
#                 "favourites_count": 2898,
#                 "id": 19955482,
#                 "has_extended_profile": false,
#                 "protected": false,
#                 "following": false,
#                 "friends_count": 794,
#                 "name": "Z100 New York",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/rj8vV1NgSp",
#                                 "expanded_url": "http://Z100.com",
#                                 "display_url": "Z100.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "location": "New York, NY.",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/790103653/6a590598f9fcfc998da8299e3618951b.gif",
#                 "utc_offset": null,
#                 "default_profile_image": false,
#                 "url": "https://t.co/rj8vV1NgSp",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/750339625768538112/Uq3ITe8F_normal.jpg",
#                 "description": "New York's #1 Hit Music Station @ElvisDuranShow 6a-10a | @RyanSeacrest 10a-2p | @RadioMoBounce 2p-6p | @MaxwellsHouse 6p-10p | @Shelley_Rome 10p-2a \u23aa",
#                 "follow_request_sent": false,
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/750339625768538112/Uq3ITe8F_normal.jpg",
#                 "default_profile": false,
#                 "profile_text_color": "666666",
#                 "profile_background_color": "009AAB",
#                 "contributors_enabled": false,
#                 "profile_sidebar_fill_color": "252429",
#                 "id_str": "19955482",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/19955482/1469220186",
#                 "profile_background_tile": false,
#                 "statuses_count": 55940,
#                 "screen_name": "Z100NewYork",
#                 "geo_enabled": true,
#                 "created_at": "Tue Feb 03 05:06:40 +0000 2009",
#                 "is_translator": false,
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "verified": true
#             },
#             "place": {
#                 "url": "https://api.twitter.com/1.1/geo/id/27485069891a7938.json",
#                 "country_code": "US",
#                 "full_name": "New York, NY",
#                 "bounding_box": {
#                     "type": "Polygon",
#                     "coordinates": [
#                         [
#                             [
#                                 -74.255641,
#                                 40.495865
#                             ],
#                             [
#                                 -73.699793,
#                                 40.495865
#                             ],
#                             [
#                                 -73.699793,
#                                 40.91533
#                             ],
#                             [
#                                 -74.255641,
#                                 40.91533
#                             ]
#                         ]
#                     ]
#                 },
#                 "name": "New York",
#                 "contained_within": [],
#                 "place_type": "admin",
#                 "id": "27485069891a7938",
#                 "attributes": {},
#                 "country": "United States"
#             }
#         },
#         "created_at": "Tue Sep 13 14:09:49 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": null,
#             "profile_link_color": "0084B4",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "listed_count": 181,
#             "followers_count": 2829,
#             "is_translation_enabled": false,
#             "favourites_count": 323328,
#             "id": 2922172126,
#             "has_extended_profile": true,
#             "protected": false,
#             "following": false,
#             "friends_count": 586,
#             "name": "King J.R \u2728",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": null,
#             "default_profile_image": false,
#             "url": null,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/768801519433121792/vyiIW33F_normal.jpg",
#             "description": "spreading Good Vibes To Everyone\u270c\ud83c\udffd\ufe0f\u270c\ud83c\udffd\u2728 who Follows me thank you for everything!!!        Happy as ever with how my life is right now",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/768801519433121792/vyiIW33F_normal.jpg",
#             "default_profile": true,
#             "profile_text_color": "333333",
#             "profile_background_color": "C0DEED",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "2922172126",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2922172126/1473480869",
#             "profile_background_tile": false,
#             "statuses_count": 211878,
#             "screen_name": "king_mystic",
#             "geo_enabled": false,
#             "created_at": "Sun Dec 14 23:13:18 +0000 2014",
#             "is_translator": false,
#             "profile_sidebar_border_color": "C0DEED",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775697659847962624,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         14,
#                         20
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         47,
#                         54
#                     ],
#                     "text": "MashUp"
#                 },
#                 {
#                     "indices": [
#                         75,
#                         78
#                     ],
#                     "text": "np"
#                 },
#                 {
#                     "indices": [
#                         103,
#                         111
#                     ],
#                     "text": "PlayNow"
#                 },
#                 {
#                     "indices": [
#                         112,
#                         130
#                     ],
#                     "text": "TuesdayMotivation"
#                 },
#                 {
#                     "indices": [
#                         131,
#                         138
#                     ],
#                     "text": "Tiller"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/6ohX92cnFi",
#                     "expanded_url": "https://soundcloud.com/djmr/kanye-father-stretch-my-hands-mash-up?utm_source=soundcloud&utm_campaign=share&utm_medium=twitter",
#                     "display_url": "soundcloud.com/djmr/kanye-fat\u2026",
#                     "indices": [
#                         79,
#                         102
#                     ]
#                 }
#             ]
#         },
#         "text": "NEW REMIX!!!! #Kanye - Father Stretch my hands #MashUp\u2019 by Dj Mr. Carolina #np https://t.co/6ohX92cnFi #PlayNow #TuesdayMotivation #Tiller",
#         "retweet_count": 0,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775697659847962624",
#         "created_at": "Tue Sep 13 14:08:28 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Eastern Time (US & Canada)",
#             "profile_link_color": "4A913C",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/686695108/a9aa3a7ad8e0eef4e1b9b46ef0a5a572.jpeg",
#             "listed_count": 39,
#             "followers_count": 868,
#             "is_translation_enabled": false,
#             "favourites_count": 475,
#             "id": 310009355,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 781,
#             "name": "I\u0365\u0365\u0365\u0365\u0365NINJAPI\u0365\u0365\u0365\u0365\u0365\u0365",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/41Shm3baB3",
#                             "expanded_url": "https://soundcloud.com/djmr",
#                             "display_url": "soundcloud.com/djmr",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "In Your Imagination",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/686695108/a9aa3a7ad8e0eef4e1b9b46ef0a5a572.jpeg",
#             "utc_offset": -14400,
#             "default_profile_image": false,
#             "url": "https://t.co/41Shm3baB3",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/485108750584254464/L4OV3rAm_normal.jpeg",
#             "description": "World Class Dj That's Out of This World CEO of Galactic Photos & Ninjapendent Clothing #UNCG Grad Film Maker, Dj, Producer.",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/485108750584254464/L4OV3rAm_normal.jpeg",
#             "default_profile": false,
#             "profile_text_color": "333333",
#             "profile_background_color": "C0DEED",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "310009355",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/310009355/1375498949",
#             "profile_background_tile": true,
#             "statuses_count": 24606,
#             "screen_name": "Dj_MrCarolina",
#             "geo_enabled": true,
#             "created_at": "Fri Jun 03 01:46:05 +0000 2011",
#             "is_translator": false,
#             "profile_sidebar_border_color": "FFFFFF",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775696605991280640,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         28,
#                         34
#                     ],
#                     "text": "KANYE"
#                 },
#                 {
#                     "indices": [
#                         55,
#                         61
#                     ],
#                     "text": "YEEZY"
#                 },
#                 {
#                     "indices": [
#                         86,
#                         93
#                     ],
#                     "text": "repost"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/8j0goLXUSH",
#                     "expanded_url": "https://www.instagram.com/p/BKTH1xXA5hU/",
#                     "display_url": "instagram.com/p/BKTH1xXA5hU/",
#                     "indices": [
#                         94,
#                         117
#                     ]
#                 }
#             ]
#         },
#         "text": "Meanwhile last night at the #KANYE concert, Looks like #YEEZY got superpowers now! \ud83d\ude02\ud83d\ude02 #repost https://t.co/8j0goLXUSH",
#         "retweet_count": 0,
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775696605991280640",
#         "created_at": "Tue Sep 13 14:04:17 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "London",
#             "profile_link_color": "000000",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/563080993712513024/btCywCWj.png",
#             "listed_count": 22,
#             "followers_count": 29820,
#             "is_translation_enabled": false,
#             "favourites_count": 198,
#             "id": 218082740,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 1692,
#             "name": "100FlavoursUK",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/PNOGjepfFc",
#                             "expanded_url": "http://www.100Flavours.co.uk",
#                             "display_url": "100Flavours.co.uk",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "London",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/563080993712513024/btCywCWj.png",
#             "utc_offset": 3600,
#             "default_profile_image": false,
#             "url": "https://t.co/PNOGjepfFc",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/772066833826545664/bIiX0lNb_normal.jpg",
#             "description": "PR & Online Publication - Enquiries: Contact@100Flavours.co.uk",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/772066833826545664/bIiX0lNb_normal.jpg",
#             "default_profile": false,
#             "profile_text_color": "000000",
#             "profile_background_color": "FFFFFF",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "D19A04",
#             "id_str": "218082740",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/218082740/1458979031",
#             "profile_background_tile": false,
#             "statuses_count": 11694,
#             "screen_name": "100FlavoursUK",
#             "geo_enabled": false,
#             "created_at": "Sun Nov 21 11:02:42 +0000 2010",
#             "is_translator": false,
#             "profile_sidebar_border_color": "FFFFFF",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775695587886837764,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         33,
#                         41
#                     ],
#                     "text": "hipster"
#                 },
#                 {
#                     "indices": [
#                         42,
#                         48
#                     ],
#                     "text": "kanye"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": []
#         },
#         "text": "meditation AND EAST ALLEN STREET #hipster #kanye",
#         "retweet_count": 0,
#         "source": "<a href=\"http://www.projextra.ca\" rel=\"nofollow\">HipsterTweets</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775695587886837764",
#         "created_at": "Tue Sep 13 14:00:14 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Eastern Time (US & Canada)",
#             "profile_link_color": "ABB8C2",
#             "profile_use_background_image": false,
#             "notifications": false,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "listed_count": 11,
#             "followers_count": 23,
#             "is_translation_enabled": false,
#             "favourites_count": 0,
#             "id": 703385241000550401,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 1,
#             "name": "Hipster Kanye",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": -14400,
#             "url": null,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/703401706420379652/wpwf-Bn0_normal.jpg",
#             "description": "A mix of Ruby, Faker::Hipster and Kanye! Created by @xenilk",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/703401706420379652/wpwf-Bn0_normal.jpg",
#             "default_profile": false,
#             "profile_text_color": "000000",
#             "profile_background_color": "000000",
#             "contributors_enabled": false,
#             "default_profile_image": false,
#             "id_str": "703385241000550401",
#             "profile_sidebar_fill_color": "000000",
#             "profile_background_tile": false,
#             "statuses_count": 2562,
#             "screen_name": "KanyeHipster",
#             "geo_enabled": false,
#             "created_at": "Sat Feb 27 01:04:44 +0000 2016",
#             "is_translator": false,
#             "profile_sidebar_border_color": "000000",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775695301780930565,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         14,
#                         20
#                     ],
#                     "text": "Kanye"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": []
#         },
#         "text": "It looks like #Kanye used the force on that guy trying to climb the stage",
#         "retweet_count": 0,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775695301780930565",
#         "created_at": "Tue Sep 13 13:59:06 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Atlantic Time (Canada)",
#             "profile_link_color": "0084B4",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "listed_count": 1,
#             "followers_count": 361,
#             "is_translation_enabled": false,
#             "favourites_count": 6920,
#             "id": 565733535,
#             "has_extended_profile": true,
#             "protected": false,
#             "following": false,
#             "friends_count": 410,
#             "name": "\u00abethan\u00bb",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "Ontario, Canada",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": -10800,
#             "default_profile_image": false,
#             "url": null,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/700506350174892032/b_n1j3nY_normal.jpg",
#             "description": "Ryerson U Media Production. Photography nerd, analog medium enthusiast.",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/700506350174892032/b_n1j3nY_normal.jpg",
#             "default_profile": true,
#             "profile_text_color": "333333",
#             "profile_background_color": "C0DEED",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "565733535",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/565733535/1473257043",
#             "profile_background_tile": false,
#             "statuses_count": 608,
#             "screen_name": "EthanCreer",
#             "geo_enabled": true,
#             "created_at": "Sat Apr 28 18:41:01 +0000 2012",
#             "is_translator": false,
#             "profile_sidebar_border_color": "C0DEED",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775694385639895040,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 1,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         87,
#                         99
#                     ],
#                     "text": "NeverForget"
#                 },
#                 {
#                     "indices": [
#                         100,
#                         106
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         107,
#                         119
#                     ],
#                     "text": "TaylorSwift"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": []
#         },
#         "text": "It's the 7th anniversary of one of the most controversial days in our nation's history #NeverForget #Kanye #TaylorSwift",
#         "retweet_count": 0,
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775694385639895040",
#         "created_at": "Tue Sep 13 13:55:27 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Central Time (US & Canada)",
#             "profile_link_color": "1B95E0",
#             "profile_use_background_image": false,
#             "notifications": false,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "listed_count": 13,
#             "followers_count": 131,
#             "is_translation_enabled": false,
#             "favourites_count": 1133,
#             "id": 361941090,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 87,
#             "name": "Mike",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": -18000,
#             "default_profile_image": false,
#             "url": null,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/3222793550/03d02585f39953f7f363d2aef3aba83c_normal.jpeg",
#             "description": "29/Male/Minnesota",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/3222793550/03d02585f39953f7f363d2aef3aba83c_normal.jpeg",
#             "default_profile": false,
#             "profile_text_color": "000000",
#             "profile_background_color": "000000",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "000000",
#             "id_str": "361941090",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/361941090/1422479901",
#             "profile_background_tile": false,
#             "statuses_count": 11600,
#             "screen_name": "uofmike",
#             "geo_enabled": false,
#             "created_at": "Thu Aug 25 15:51:00 +0000 2011",
#             "is_translator": false,
#             "profile_sidebar_border_color": "000000",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "fr",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775693830813261828,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         21,
#                         27
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         28,
#                         36
#                     ],
#                     "text": "Atlanta"
#                 },
#                 {
#                     "indices": [
#                         37,
#                         56
#                     ],
#                     "text": "saintpablotour2016"
#                 },
#                 {
#                     "indices": [
#                         57,
#                         63
#                     ],
#                     "text": "yeezy"
#                 },
#                 {
#                     "indices": [
#                         64,
#                         72
#                     ],
#                     "text": "amazing"
#                 },
#                 {
#                     "indices": [
#                         73,
#                         78
#                     ],
#                     "text": "tour"
#                 },
#                 {
#                     "indices": [
#                         79,
#                         83
#                     ],
#                     "text": "lit"
#                 },
#                 {
#                     "indices": [
#                         84,
#                         97
#                     ],
#                     "text": "postoftheday"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/Wufo6slcBU",
#                     "expanded_url": "https://www.instagram.com/p/BKTGk_4gLga/",
#                     "display_url": "instagram.com/p/BKTGk_4gLga/",
#                     "indices": [
#                         98,
#                         121
#                     ]
#                 }
#             ]
#         },
#         "text": "[Saint Pablo Tour] \n\n#Kanye #Atlanta #saintpablotour2016 #yeezy #amazing #tour #lit #postoftheday https://t.co/Wufo6slcBU",
#         "retweet_count": 0,
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775693830813261828",
#         "created_at": "Tue Sep 13 13:53:15 +0000 2016",
#         "metadata": {
#             "iso_language_code": "fr",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Atlantic Time (Canada)",
#             "profile_link_color": "0C0C0D",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/522647249629638656/b6u3l7lS.jpeg",
#             "listed_count": 6,
#             "followers_count": 181,
#             "is_translation_enabled": false,
#             "favourites_count": 1127,
#             "id": 878970662,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 287,
#             "name": "KRUSH",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/yQsE26ENFm",
#                             "expanded_url": "https://geo.itunes.apple.com/us/album/keep-renovating-until-success/id1136075224?app=itunes",
#                             "display_url": "geo.itunes.apple.com/us/album/keep-\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/PmYAunUPGd",
#                             "expanded_url": "https://soundcloud.com/krush",
#                             "display_url": "soundcloud.com/krush",
#                             "indices": [
#                                 74,
#                                 97
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "location": "",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/522647249629638656/b6u3l7lS.jpeg",
#             "utc_offset": -10800,
#             "default_profile_image": false,
#             "url": "https://t.co/yQsE26ENFm",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/651781724574126080/NqoOudep_normal.jpg",
#             "description": "Artist (K.R.U.S.H.) Instagram-YoThatsKrush Bookings @krushmusiq@gmail.com https://t.co/PmYAunUPGd (EP/ALBUM) drops Aug.4th  but available for pre-order",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/651781724574126080/NqoOudep_normal.jpg",
#             "default_profile": false,
#             "profile_text_color": "333333",
#             "profile_background_color": "100AB0",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "878970662",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/878970662/1444232051",
#             "profile_background_tile": true,
#             "statuses_count": 4025,
#             "screen_name": "YoThatsKrush",
#             "geo_enabled": true,
#             "created_at": "Sun Oct 14 00:06:12 +0000 2012",
#             "is_translator": false,
#             "profile_sidebar_border_color": "FFFFFF",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "es",
#         "geo": {
#             "type": "Point",
#             "coordinates": [
#                 38.8951,
#                 -77.0367
#             ]
#         },
#         "in_reply_to_user_id": null,
#         "id": 775693745522024449,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": {
#             "type": "Point",
#             "coordinates": [
#                 -77.0367,
#                 38.8951
#             ]
#         },
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         18,
#                         32
#                     ],
#                     "text": "merchandising"
#                 },
#                 {
#                     "indices": [
#                         33,
#                         39
#                     ],
#                     "text": "kanye"
#                 },
#                 {
#                     "indices": [
#                         40,
#                         50
#                     ],
#                     "text": "kanyewest"
#                 },
#                 {
#                     "indices": [
#                         51,
#                         62
#                     ],
#                     "text": "elecciones"
#                 },
#                 {
#                     "indices": [
#                         63,
#                         68
#                     ],
#                     "text": "eeuu"
#                 },
#                 {
#                     "indices": [
#                         69,
#                         77
#                     ],
#                     "text": "hillary"
#                 },
#                 {
#                     "indices": [
#                         78,
#                         84
#                     ],
#                     "text": "trump"
#                 },
#                 {
#                     "indices": [
#                         85,
#                         89
#                     ],
#                     "text": "usa"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/iR2IqermYe",
#                     "expanded_url": "https://www.instagram.com/p/BKTGiX8Biba/",
#                     "display_url": "instagram.com/p/BKTGiX8Biba/",
#                     "indices": [
#                         91,
#                         114
#                     ]
#                 }
#             ]
#         },
#         "text": "La tercera v\u00eda \ud83c\udfb6\ud83d\ude0e\n#merchandising #kanye #kanyewest #elecciones #eeuu #hillary #trump #usa\u2026 https://t.co/iR2IqermYe",
#         "retweet_count": 0,
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775693745522024449",
#         "created_at": "Tue Sep 13 13:52:55 +0000 2016",
#         "metadata": {
#             "iso_language_code": "es",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "es",
#             "time_zone": "Ljubljana",
#             "profile_link_color": "0084B4",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "listed_count": 59,
#             "followers_count": 841,
#             "is_translation_enabled": true,
#             "favourites_count": 981,
#             "id": 1392214621,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 1164,
#             "name": "0034 C\u00f3digo Expat",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/o8toN071Q2",
#                             "expanded_url": "http://www.0034expat.com",
#                             "display_url": "0034expat.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "utc_offset": 7200,
#             "default_profile_image": false,
#             "url": "http://t.co/o8toN071Q2",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/378800000119954768/f0b5d4ded6d12c1fb1e46e59c69026a1_normal.jpeg",
#             "description": "La primera publicaci\u00f3n para espa\u00f1oles en el extranjero. \nDe la mano de @PRISA, @BBVA y @UNAOC",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000119954768/f0b5d4ded6d12c1fb1e46e59c69026a1_normal.jpeg",
#             "default_profile": true,
#             "profile_text_color": "333333",
#             "profile_background_color": "C0DEED",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "1392214621",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1392214621/1413263600",
#             "profile_background_tile": false,
#             "statuses_count": 2685,
#             "screen_name": "0034_expat",
#             "geo_enabled": true,
#             "created_at": "Tue Apr 30 14:28:28 +0000 2013",
#             "is_translator": false,
#             "profile_sidebar_border_color": "C0DEED",
#             "verified": false
#         },
#         "place": {
#             "url": "https://api.twitter.com/1.1/geo/id/01fbe706f872cb32.json",
#             "country_code": "US",
#             "full_name": "Washington, DC",
#             "bounding_box": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -77.119401,
#                             38.801826
#                         ],
#                         [
#                             -76.909396,
#                             38.801826
#                         ],
#                         [
#                             -76.909396,
#                             38.9953797
#                         ],
#                         [
#                             -77.119401,
#                             38.9953797
#                         ]
#                     ]
#                 ]
#             },
#             "name": "Washington",
#             "contained_within": [],
#             "place_type": "city",
#             "id": "01fbe706f872cb32",
#             "attributes": {},
#             "country": "United States"
#         }
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775692945278271488,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         0,
#                         10
#                     ],
#                     "text": "KanyeWest"
#                 },
#                 {
#                     "indices": [
#                         38,
#                         43
#                     ],
#                     "text": "TLOP"
#                 },
#                 {
#                     "indices": [
#                         46,
#                         52
#                     ],
#                     "text": "Kanye"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/kBjcm8i0kb",
#                     "expanded_url": "https://www.instagram.com/p/BKTGLPEA_b5/",
#                     "display_url": "instagram.com/p/BKTGLPEA_b5/",
#                     "indices": [
#                         53,
#                         76
#                     ]
#                 }
#             ]
#         },
#         "text": "#KanyeWest fan does a lil too much... #TLOP \n\n#Kanye https://t.co/kBjcm8i0kb",
#         "retweet_count": 0,
# ...
#                         "large": {
#                             "w": 1024,
#                             "resize": "fit",
#                             "h": 768
#                         },
#                         "medium": {
#                             "w": 1024,
#                             "resize": "fit",
#                             "h": 768
#                         },
#                         "small": {
#                             "w": 680,
#                             "resize": "fit",
#                             "h": 510
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "resize": "crop",
#                             "h": 150
#                         }
#                     },
#                     "type": "photo",
#                     "display_url": "pic.twitter.com/um38lNcg9d",
#                     "media_url_https": "https://pbs.twimg.com/media/CsM62S0XgAESgq-.jpg",
#                     "id": 775528265276686337,
#                     "media_url": "http://pbs.twimg.com/media/CsM62S0XgAESgq-.jpg",
#                     "indices": [
#                         70,
#                         93
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "text": "I read about the floating stage, but damn, #Kanye. #StPablo ##Atlanta https://t.co/um38lNcg9d",
#         "retweet_count": 0,
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775528641920925696",
#         "created_at": "Tue Sep 13 02:56:51 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": null,
#             "profile_link_color": "FA743E",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/344918034409495633/da9886e58c6b0cc21f78f1364a06c23e.jpeg",
#             "listed_count": 14,
#             "followers_count": 430,
#             "is_translation_enabled": false,
#             "favourites_count": 5,
#             "id": 1517440645,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 762,
#             "name": "Eliott C. McLaughlin",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/D81kRFHJNd",
#                             "expanded_url": "http://cnn.it/1FIb4ch",
#                             "display_url": "cnn.it/1FIb4ch",
#                             "indices": [
#                                 0,
#                                 22
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "Reppin' #O4W, #ATL",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/344918034409495633/da9886e58c6b0cc21f78f1364a06c23e.jpeg",
#             "utc_offset": null,
#             "default_profile_image": false,
#             "url": "http://t.co/D81kRFHJNd",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/344513261578878128/7ff1ca460e75bf47d50ce38879c321f3_normal.jpeg",
#             "description": "Writer and general eclectic. This account's for fun: music, sports, clothes, travel, food, the like. My Clark Kent ish can be found here: @EliottCNN.",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/344513261578878128/7ff1ca460e75bf47d50ce38879c321f3_normal.jpeg",
#             "default_profile": false,
#             "profile_text_color": "333333",
#             "profile_background_color": "C0DEED",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "1517440645",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1517440645/1371245053",
#             "profile_background_tile": false,
#             "statuses_count": 3543,
#             "screen_name": "furlinedPumas",
#             "geo_enabled": true,
#             "created_at": "Fri Jun 14 19:48:44 +0000 2013",
#             "is_translator": false,
#             "profile_sidebar_border_color": "FFFFFF",
#             "verified": false
#         },
#         "place": null
#     },
#     {
#         "lang": "en",
#         "geo": {
#             "type": "Point",
#             "coordinates": [
#                 33.75750872,
#                 -84.39600736
#             ]
#         },
#         "in_reply_to_user_id": null,
#         "id": 775528611059273728,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": {
#             "type": "Point",
#             "coordinates": [
#                 -84.39600736,
#                 33.75750872
#             ]
#         },
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         27,
#                         37
#                     ],
#                     "text": "kanyewest"
#                 },
#                 {
#                     "indices": [
#                         38,
#                         44
#                     ],
#                     "text": "kanye"
#                 },
#                 {
#                     "indices": [
#                         45,
#                         60
#                     ],
#                     "text": "saintpablotour"
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/BJJSYM2zgi",
#                     "expanded_url": "https://www.instagram.com/p/BKR7cdmD7lm/",
#                     "display_url": "instagram.com/p/BKR7cdmD7lm/",
#                     "indices": [
#                         77,
#                         100
#                     ]
#                 }
#             ]
#         },
#         "text": "Bruh, who does this?!? \ud83d\ude33\ud83d\ude33\ud83d\ude33 #kanyewest #kanye #saintpablotour @ Philips Arena https://t.co/BJJSYM2zgi",
#         "retweet_count": 0,
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775528611059273728",
#         "created_at": "Tue Sep 13 02:56:44 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Eastern Time (US & Canada)",
#             "profile_link_color": "009999",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#             "listed_count": 83,
#             "followers_count": 2939,
#             "is_translation_enabled": false,
#             "favourites_count": 492,
#             "id": 18424313,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 712,
#             "name": "Donnie Leapheart",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/6VX8EMpn6L",
#                             "expanded_url": "http://www.OsirisTheSeries.com/",
#                             "display_url": "OsirisTheSeries.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "Atlanta",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#             "utc_offset": -14400,
#             "default_profile_image": false,
#             "url": "https://t.co/6VX8EMpn6L",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/775053043549208576/rbf2wGWg_normal.jpg",
#             "description": "Creator of OSIRIS, the Award-Winning scifi/action Film & Series. Film/TV producer, director, screenwriter, editor. I speak my opinions uncensored, forgive me.",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/775053043549208576/rbf2wGWg_normal.jpg",
#             "default_profile": false,
#             "profile_text_color": "333333",
#             "profile_background_color": "131516",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "EFEFEF",
#             "id_str": "18424313",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/18424313/1438871618",
#             "profile_background_tile": true,
#             "statuses_count": 14036,
#             "screen_name": "DonnieLeap",
#             "geo_enabled": true,
#             "created_at": "Sun Dec 28 08:04:42 +0000 2008",
#             "is_translator": false,
#             "profile_sidebar_border_color": "EEEEEE",
#             "verified": false
#         },
#         "place": {
#             "url": "https://api.twitter.com/1.1/geo/id/8173485c72e78ca5.json",
#             "country_code": "US",
#             "full_name": "Atlanta, GA",
#             "bounding_box": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             -84.576827,
#                             33.6475029
#                         ],
#                         [
#                             -84.289385,
#                             33.6475029
#                         ],
#                         [
#                             -84.289385,
#                             33.8868859
#                         ],
#                         [
#                             -84.576827,
#                             33.8868859
#                         ]
#                     ]
#                 ]
#             },
#             "name": "Atlanta",
#             "contained_within": [],
#             "place_type": "city",
#             "id": "8173485c72e78ca5",
#             "attributes": {},
#             "country": "United States"
#         }
#     },
#     {
#         "lang": "en",
#         "geo": null,
#         "in_reply_to_user_id": null,
#         "id": 775527451808047104,
#         "is_quote_status": false,
#         "in_reply_to_screen_name": null,
#         "coordinates": null,
#         "possibly_sensitive": false,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_status_id": null,
#         "favorited": false,
#         "truncated": false,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         0,
#                         15
#                     ],
#                     "text": "kixionaryworld"
#                 },
#                 {
#                     "indices": [
#                         16,
#                         21
#                     ],
#                     "text": "dope"
#                 },
#                 {
#                     "indices": [
#                         58,
#                         64
#                     ],
#                     "text": "kanye"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "name": "Mache Custom Kicks",
#                     "indices": [
#                         22,
#                         31
#                     ],
#                     "id": 45136578,
#                     "screen_name": "MACHE275",
#                     "id_str": "45136578"
#                 }
#             ],
#             "symbols": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/pRrdw8rByH",
#                     "expanded_url": "https://www.instagram.com/p/BKR66rYBaCJ/",
#                     "display_url": "instagram.com/p/BKR66rYBaCJ/",
#                     "indices": [
#                         65,
#                         88
#                     ]
#                 }
#             ]
#         },
#         "text": "#kixionaryworld #dope @mache275 took it back to the 808's #kanye https://t.co/pRrdw8rByH",
#         "retweet_count": 0,
#         "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#         "contributors": null,
#         "retweeted": false,
#         "in_reply_to_user_id_str": null,
#         "id_str": "775527451808047104",
#         "created_at": "Tue Sep 13 02:52:07 +0000 2016",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "user": {
#             "lang": "en",
#             "time_zone": "Central Time (US & Canada)",
#             "profile_link_color": "990000",
#             "profile_use_background_image": true,
#             "notifications": false,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/757482721/61a9ea54a510ae7718a11b3057448b57.jpeg",
#             "listed_count": 84,
#             "followers_count": 963,
#             "is_translation_enabled": false,
#             "favourites_count": 457,
#             "id": 19638945,
#             "has_extended_profile": false,
#             "protected": false,
#             "following": false,
#             "friends_count": 706,
#             "name": "L J Verified",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/MjtUwuztWO",
#                             "expanded_url": "http://kixionary.com",
#                             "display_url": "kixionary.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "Miami Carol City \ue03d",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/757482721/61a9ea54a510ae7718a11b3057448b57.jpeg",
#             "utc_offset": -18000,
#             "default_profile_image": false,
#             "url": "http://t.co/MjtUwuztWO",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/626609862466666497/ZCJcH4iD_normal.jpg",
#             "description": "I work while you sleep, I live while you dream. kixbusiness@gmail.com",
#             "follow_request_sent": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/626609862466666497/ZCJcH4iD_normal.jpg",
#             "default_profile": false,
#             "profile_text_color": "333333",
#             "profile_background_color": "EBEBEB",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "F3F3F3",
#             "id_str": "19638945",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/19638945/1381647651",
#             "profile_background_tile": true,
#             "statuses_count": 31495,
#             "screen_name": "kixionary",
#             "geo_enabled": true,
#             "created_at": "Wed Jan 28 06:09:49 +0000 2009",
#             "is_translator": false,
#             "profile_sidebar_border_color": "FFFFFF",
#             "verified": false
#         },
#         "place": null
#     }
# ]

# %% [markdown]
# # Example 6. Extracting text, screen names, and hashtags from tweets

# %%
import time


status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @Z100NewYork: #KanyeWest fan attempts to climb to the top of #Kanye's floating stage at this #SaintPabloTour in #Atlanta! WATCH https://\u2026",
#  "NEW REMIX!!!! #Kanye - Father Stretch my hands #MashUp\u2019 by Dj Mr. Carolina #np https://t.co/6ohX92cnFi #PlayNow #TuesdayMotivation #Tiller",
#  "Meanwhile last night at the #KANYE concert, Looks like #YEEZY got superpowers now! \ud83d\ude02\ud83d\ude02 #repost https://t.co/8j0goLXUSH",
#  "meditation AND EAST ALLEN STREET #hipster #kanye",
#  "It looks like #Kanye used the force on that guy trying to climb the stage"
# ]
# [
#  "Z100NewYork",
#  "Zatara5555",
#  "HOT97",
#  "CentricApp",
#  "mahoganydane1"
# ]
# [
#  "KanyeWest",
#  "Kanye",
#  "SaintPabloTour",
#  "Atlanta",
#  "Kanye"
# ]
# [
#  "RT",
#  "@Z100NewYork:",
#  "#KanyeWest",
#  "fan",
#  "attempts"
# ]

# %% [markdown]
# # Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('#Kanye', 115), ('#kanye', 66), ('the', 60), ('RT', 51), ('to', 37), ('#SaintPabloTour', 29), ('in', 25), ('I', 23), ('a', 22), ('and', 21)]
# [('KCJ_Swish', 8), ('kanyewest', 7), ('Billboard_TH', 6), ('EyeKonik', 4), ('halleberry', 3), ('SocialUnderGrnd', 3), ('wmag', 3), ('Bonasupernova', 3), ('mahoganydane1', 3), ('CentricApp', 2)]
# [('Kanye', 126), ('kanye', 69), ('SaintPabloTour', 29), ('saintpablotour', 20), ('yeezy', 16), ('kanyewest', 14), ('hipster', 10), ('Yeezus', 10), ('KanyeWest', 8), ('Drake', 8)]

# %% [markdown]
# # Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +-----------------+-------+
# | Word            | Count |
# +-----------------+-------+
# | #Kanye          |   115 |
# | #kanye          |    66 |
# | the             |    60 |
# | RT              |    51 |
# | to              |    37 |
# | #SaintPabloTour |    29 |
# | in              |    25 |
# | I               |    23 |
# | a               |    22 |
# | and             |    21 |
# +-----------------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | KCJ_Swish       |     8 |
# | kanyewest       |     7 |
# | Billboard_TH    |     6 |
# | EyeKonik        |     4 |
# | halleberry      |     3 |
# | SocialUnderGrnd |     3 |
# | wmag            |     3 |
# | Bonasupernova   |     3 |
# | mahoganydane1   |     3 |
# | CentricApp      |     2 |
# +-----------------+-------+
# +----------------+-------+
# | Hashtag        | Count |
# +----------------+-------+
# | Kanye          |   126 |
# | kanye          |    69 |
# | SaintPabloTour |    29 |
# | saintpablotour |    20 |
# | yeezy          |    16 |
# | kanyewest      |    14 |
# | hipster        |    10 |
# | Yeezus         |    10 |
# | KanyeWest      |     8 |
# | Drake          |     8 |
# +----------------+-------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.4584103512014787
# 0.6262626262626263
# 0.3669849931787176
# 13.525

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-----------------+----------------------------------------------------+
# | Count | Screen Name     | Text                                               |
# +-------+-----------------+----------------------------------------------------+
# | 985   | elizabethhdre   | RT @elizabethhdre: Another jacket, another         |
# |       |                 | painting. #yeezus #kanye 🎓 https://t.co/RmaCD85KdX |
# | 985   | elizabethhdre   | RT @elizabethhdre: Another jacket, another         |
# |       |                 | painting. #yeezus #kanye 🎓 https://t.co/RmaCD85KdX |
# | 554   | SarantosMelogia | RT @SarantosMelogia: FUNNY!!                       |
# |       |                 |                                                    |
# |       |                 | https://t.co/LQYsOIiqXn                            |
# |       |                 |                                                    |
# |       |                 | #jamescorden                                       |
# |       |                 | #kanye                                             |
# |       |                 | #fade                                              |
# |       |                 | #musicvideo                                        |
# |       |                 | #musicvideoalert                                   |
# |       |                 | #mtv                                               |
# |       |                 | #funny                                             |
# |       |                 | #videooftheday ht…                                 |
# | 360   | BlackBoySocials | RT @BlackBoySocials: Here is the entire Fade       |
# |       |                 | video. Enjoy accordingly. #Kanye #TeyanaTaylor     |
# |       |                 | https://t.co/2zLkg3mDGD …                          |
# | 360   | BlackBoySocials | RT @BlackBoySocials: Here is the entire Fade       |
# |       |                 | video. Enjoy accordingly. #Kanye #TeyanaTaylor     |
# |       |                 | https://t.co/2zLkg3mDGD …                          |
# +-------+-----------------+----------------------------------------------------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 11. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# # Example 12. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [48, 3, 1, 1, 985, 123, 2, 2, 123, 2, 123, 2, 123, 2, 2, 2, 1, 1, 360, 1, 554, 2, 1, 3, 1, 1, 118, 3, 118, 1, 1, 2, 2, 1, 1, 3, 360, 204, 204, 3, 985, 2, 1, 1, 360]
