# %% [markdown]
# ### Notebook provides data visualizations for:
#
# * **Most expensive treatments**
#
# * **Most expensive treatments for each state**
#
# * **Rank by cost at each state (per treatment)**
#
# * **Shows cheaper providers that are available within the state (per treatment)**
#
# * **Normalized distribution of inpatients across treatments for each state**
#
# ============================================================================

# %%
import pandas as pd
import numpy as np
import os

# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('inpatientCharges_subset.csv')

# %%
print("Unique DRG's: %d" % df['DRG Definition'].unique().shape)
print("Unique Provider ID's: %d" % df['Provider Id'].unique().shape)
print("Unique Cities: %d" % df['Provider City'].unique().shape)
# Out:
# Unique DRG's: 100
# Unique Provider ID's: 103
# Unique Cities: 8

# %%
# remove white spaces from left and right of column names
df.columns = [column.strip() for column in df.columns]

# %%
# remove dollar signs
for column in ['Average Covered Charges', 'Average Total Payments', 'Average Medicare Payments']:
    df[column] = df[column].map(lambda x: x[1:])
    df[column] = pd.to_numeric(df[column])

# %%
# get 'DRG Definition' and 'Total Discharges' columns, group by 'DRG Definition' and count number of discharges per 
# 'DRG Definition'.  In summary, this code tells us how many discharges exist for each 'DRG Definition'.
agg_columns = ['count']
groupby_drg = df[['DRG Definition', 'Total Discharges']].groupby(by='DRG Definition').agg(agg_columns)
groupby_drg.columns = groupby_drg.columns.get_level_values(0)

# %%
# get top N DRG's determined by Total Discharges
num_drgs = 5
top_drg = groupby_drg[:num_drgs].sort_values(by='Total Discharges', ascending=[False])

# %%
# display top num_drgs DRG's
for drg in top_drg.iterrows():
    print(drg[0])
# Out:
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC

# %%
client_drg = ['065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC',
              '066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC',
              '064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC',
              '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
              '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC']

# %%
# display costs by city for num_drgs most common procedures

for drg in top_drg.iterrows():

    specific_drg = df[ df['DRG Definition'] == drg[0] ]
    
    drg_cost_by_city = specific_drg.pivot_table(index='Provider City', columns='DRG Definition', values='Average Covered Charges', aggfunc='min')
    
    cities = [ drg_cost_by_city.index[city_index] for city_index in range(drg_cost_by_city.index.shape[0]) ]
    
    min_charges = [ drg_cost_by_city.values[city_index][0] for city_index in range(drg_cost_by_city.index.shape[0]) ]
    
    drg = drg_cost_by_city.columns[0]
    
    # bar plot
    y_pos = np.arange(len(cities))
    plt.bar(y_pos, min_charges, align='center', alpha=0.5)
    plt.xticks(y_pos, cities, rotation=90)
    plt.ylabel('Minimum Cost ($)')
    plt.xlabel('City')
    plt.title('Minimum Cost By City \n ' + drg )
    plt.show()

# %%
# DRG 
client_drg = '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC'

# Hub and Spokes
hub = 'HOUSTON'

# Survey Results
beta = {
        'person_a': 0.2,
        'person_b': 1.0,
        'person_c':0.6
       }

# %% [markdown]
# ## Here calculate the average cost of top 5 DRG

# %%
client_drg = ['065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W CC',
              '066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W/O CC/MCC',
              '064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION W MCC',
              '057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O MCC',
              '039 - EXTRACRANIAL PROCEDURES W/O CC/MCC']

# %%
travel_costs = pd.read_csv('travel_cost_matrix.csv',index_col=0)

# %%
# medication cost for top five cities
specific_drg_1 = df[ df['DRG Definition'] == client_drg[0] ]
drg_cost_by_city_1 = specific_drg_1.pivot_table(index='Provider City', 
                                            columns='DRG Definition', 
                                            values='Average Covered Charges', 
                                            aggfunc='min')
specific_drg_2 = df[ df['DRG Definition'] == client_drg[1] ]
drg_cost_by_city_2 = specific_drg_2.pivot_table(index='Provider City', 
                                            columns='DRG Definition', 
                                            values='Average Covered Charges', 
                                            aggfunc='min')
specific_drg_3 = df[ df['DRG Definition'] == client_drg[2] ]
drg_cost_by_city_3 = specific_drg_3.pivot_table(index='Provider City', 
                                            columns='DRG Definition', 
                                            values='Average Covered Charges', 
                                            aggfunc='min')
specific_drg_4 = df[ df['DRG Definition'] == client_drg[3] ]
drg_cost_by_city_4 = specific_drg_4.pivot_table(index='Provider City', 
                                            columns='DRG Definition', 
                                            values='Average Covered Charges', 
                                            aggfunc='min')
specific_drg_5 = df[ df['DRG Definition'] == client_drg[4] ]
drg_cost_by_city_5 = specific_drg_5.pivot_table(index='Provider City', 
                                            columns='DRG Definition', 
                                            values='Average Covered Charges', 
                                            aggfunc='min')

# Miami doesn't have surgery 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
line = pd.DataFrame({"039 - EXTRACRANIAL PROCEDURES W/O CC/MCC": 0}, index=['MIAMI'])
frames_5 = [line, drg_cost_by_city_5]
drg_cost_by_city_5 = pd.concat(frames_5, axis=0, join='inner')

frames = [drg_cost_by_city_1,drg_cost_by_city_2, drg_cost_by_city_3, drg_cost_by_city_4, drg_cost_by_city_5]
drg_cost_by_city = pd.concat(frames, axis=1, join='inner')
drg_cost_avg = drg_cost_by_city.mean(axis=1)
drg_cost_avg.keys()
# Out:
# Index(['ATLANTA', 'BOSTON', 'CHARLOTTE', 'CHICAGO', 'HOUSTON', 'MIAMI',
#        'PHILADELPHIA', 'WASHINGTON'],
#       dtype='object', name='Provider City')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pairwise_cost = np.zeros((8,8))

for i in range(8):
    for j in range(8):
        pairwise_cost[i,j] = list(drg_cost_avg)[i]-list(drg_cost_avg)[j]
        
pairwise_cost = pd.DataFrame(pairwise_cost, index=['ATLANTA', 'BOSTON', 'CHARLOTTE', 'CHICAGO', 'HOUSTON', 
                                                   'MIAMI', 'PHILADELPHIA', 'WASHINGTON'])
pairwise_cost.columns = ['ATLANTA', 'BOSTON', 'CHARLOTTE', 'CHICAGO', 'HOUSTON', 'MIAMI', 'PHILADELPHIA', 'WASHINGTON']

# Plot
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap using seaborn
# sns.color_palette("RdGy", 10)
# sns.palplot(sns.color_palette("RdGy", 10))
sns.heatmap(pairwise_cost, cmap = "coolwarm", vmax=.8, square=True)
plt.show()

# %% [markdown]
# In a general way, for insurance companies in each city listed in the bottom to the heatmap, they should sent their customers to cities with color blue. The darker of blue the cell appears, the more money they save from sending people away. Like for Miami and Philadelphia, it would save money from sending customers to multiple city. Red cells means sending people away can be more expensive and the insurance company should not do it.

# %%
# Get all records for client_drg
specific_drg = df[ df['DRG Definition'] == client_drg ]

# pivot table: rows = Provider City, columns = DRG Definition, values = Minimum Average Covered Charges
drg_cost_by_city = specific_drg.pivot_table(index='Provider City', 
                                            columns='DRG Definition', 
                                            values='Average Covered Charges', 
                                            aggfunc='min')

# cost of DRG in hub city
hub_drg_cost = {hub:drg_cost_by_city.ix[hub][0]}

# cost of DRG in spoke cities
spoke_drg_costs = dict()

for drg_cost_spoke in drg_cost_by_city.index[:]:
    
    if drg_cost_spoke not in hub:
        spoke_drg_costs[drg_cost_spoke] = drg_cost_by_city.ix[drg_cost_spoke][0]

# %%
print(hub_drg_cost)
print(spoke_drg_costs)
# Out:
# {'HOUSTON': 27332.759999999998}
# {'PHILADELPHIA': 21009.68, 'ATLANTA': 11189.9, 'MIAMI': 44283.0, 'WASHINGTON': 22669.970000000001, 'BOSTON': 14650.200000000001, 'CHICAGO': 16226.08, 'CHARLOTTE': 23853.560000000001}

# %%
# calcuate cost of sending client for DRG for each spoke city
total_spoke_costs = dict()

for spoke,spoke_cost in spoke_drg_costs.items():
    
    total_spoke_costs[spoke] = spoke_cost + \
                               travel_costs[hub][spoke] + \
                               beta['person_a'] * (0.2 * max(hub_drg_cost[hub] - spoke_cost, 0))

# %%
total_spoke_costs.keys()
# Out:
# dict_keys(['PHILADELPHIA', 'CHARLOTTE', 'ATLANTA', 'BOSTON', 'MIAMI', 'CHICAGO', 'WASHINGTON'])

# %%
# savings per city
print("The cost of having the procedure done in %s is $%d\n" % (hub,hub_drg_cost[hub]))

for spoke_city, spoke_cost in total_spoke_costs.items():
    
#     cost_diff = hub_drg_cost[hub] - spoke_cost
    print("The cost of having the procedure done in %s is $%d" % (spoke_city, spoke_cost) )
# Out:
# The cost of having the procedure done in HOUSTON is $27120
#
# The cost of having the procedure done in CHARLOTTE is $29295
# The cost of having the procedure done in WASHINGTON is $36977
# The cost of having the procedure done in CHICAGO is $33142
# The cost of having the procedure done in BOSTON is $17242
# The cost of having the procedure done in ATLANTA is $18185
# The cost of having the procedure done in PHILADELPHIA is $39420

# %%
# get radar axes after scales
import pygal

radar_chart = pygal.Radar()
radar_chart.title = 'cost of the procedure'
radar_chart.x_labels = ['HOUSTON', 'PHILADELPHIA', 'ATLANTA', 'CHICAGO', 'CHARLOTTE', 'BOSTON','WASHINGTON']
radar_chart.add('total costs', [27120, 40614, 18761, 33716,29481,17878, 37928])
radar_chart.render_to_file('radar_chart.svg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c78d1f4c914f> in <module>()
#       1 from pandas.tools.plotting import radviz
#       2 plt.close('all')
# ----> 3 radviz(total_spoke_costs)
#       4 plt.show()
#
# TypeError: radviz() missing 1 required positional argument: 'class_column'
